# %%
using PyPlot

# %%
x = linspace(0, 2pi, 1000)
y = sin(3x + 4cos(2x))
plot(x, y, color="red", linewidth=2.0, linestyle="--")
title("Nejnudnější graf funkce")
xlabel("TOHLE je osa x")
ylabel("TOHLE je osa y")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x7f3b6df4cf10>)
# PyObject <matplotlib.text.Text object at 0x7f3b692aca90>
